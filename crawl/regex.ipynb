# %%
# 정규식

# %% [markdown]
# #### 정규 표현식
# - 특정한 패턴과 일치하는 문자열을 검색, 치환, 제거 하는 기능을 지원
# - re 모듈 사용
#     - match(), search(), findall(), finditer(), ...
#     - [a-zA-Z] : 모든 알파벳 패턴
#     - . : \n 을 제외한 모든 문자
#     - * : 0 ~ 무한대, + : 1 ~ 무한대, ? : 0 ~ 1, {2}, {2,10} : 최소2 최대10

# %%
import re

# 검색할 패턴 작성
pattern = re.compile("D.A")

# 원본 문자열
origin = "DAA"

# 원본 문자열과 패턴이 일치하는가?
result = pattern.search(origin)
print(result)

print("패턴 시작 위치", result.start())
print("패턴 끝 위치", result.end())
print("re와 일치하는 문자열 반환", result.group())
print("패턴 위치", result.span())
# Out:
# <re.Match object; span=(0, 3), match='DAA'>
# 패턴 시작 위치 0
# 패턴 끝 위치 3
# re와 일치하는 문자열 반환 DAA
# 패턴 위치 (0, 3)

# %%
origin = "D00A"

# 원본 문자열과 패턴이 일치하는가?
result = pattern.search(origin)
print(result)
# Out:
# None

# %%
origin = "d0A D1A 0111"

# 원본 문자열과 패턴이 일치하는가?
result = pattern.search(origin) # String 에 있는 search 메소드
print(result)
# Out:
# <re.Match object; span=(4, 7), match='D1A'>

# %%
# re 에 있는 search 메소드
re.search(r"D.A","DAA")
# Out:
# <re.Match object; span=(0, 3), match='DAA'>

# %%
pattern = re.compile("D?A") # 앞에있는 D 가 최소 0 ~ 최대 1 가능, A문자가 있어야 함
print(pattern.search("A"))
print(pattern.search("DA"))
print(pattern.search("AA"))
# Out:
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 2), match='DA'>
# <re.Match object; span=(0, 1), match='A'>

# %%
pattern = re.compile("D*A") # 앞에있는 D 가 최소 0 ~ 최대 무한대 가능, A문자가 있어야 함
print(pattern.search("A"))
print(pattern.search("DA"))
print(pattern.search("DDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 2), match='DA'>
# <re.Match object; span=(0, 13), match='DDDDDDDDDDDDA'>

# %%
pattern = re.compile("D+A") # 앞에있는 D 가 최소 1 ~ 최대 무한대 가능, A문자가 있어야 함
print(pattern.search("A"))
print(pattern.search("DA"))
print(pattern.search("DDDDDDDDDDDDAA"))
# Out:
# None
# <re.Match object; span=(0, 2), match='DA'>
# <re.Match object; span=(0, 13), match='DDDDDDDDDDDDA'>

# %%
pattern = re.compile("AD{2}A") # 앞에있는 D 가 최소 2 ~ 최대 2, A문자가 있어야 함
print(pattern.search("ADA"))
print(pattern.search("ADDA"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# None
# <re.Match object; span=(0, 4), match='ADDA'>
# None

# %%
pattern = re.compile("AD{2,6}A") # 앞에있는 D 가 최소 2 ~ 최대 6, A문자가 있어야 함
print(pattern.search("ADA"))
print(pattern.search("ADDA"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# None
# <re.Match object; span=(0, 4), match='ADDA'>
# None

# %%
pattern = re.compile("[ABCDEFGabcdefg]") # 
print(pattern.search("aa1234"))
print(pattern.search("A4567"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(0, 1), match='a'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>

# %%
pattern = re.compile("[A-Ga-g]") # 
print(pattern.search("aa1234"))
print(pattern.search("A4567"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(0, 1), match='a'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>

# %%
pattern = re.compile("[A-Ga-g]+") # 
print(pattern.search("aa1234"))
print(pattern.search("A4567"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(0, 2), match='aa'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 15), match='ADDDDDDDDDDDDAA'>

# %%
pattern = re.compile("[A-Za-z]+") # 
print(pattern.search("aa1234"))
print(pattern.search("A4567"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(0, 2), match='aa'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 15), match='ADDDDDDDDDDDDAA'>

# %%
pattern = re.compile("[A-Za-z0-9]+") # 
print(pattern.search("aa1234"))
print(pattern.search("A4567"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(0, 6), match='aa1234'>
# <re.Match object; span=(0, 5), match='A4567'>
# <re.Match object; span=(0, 15), match='ADDDDDDDDDDDDAA'>

# %%
pattern = re.compile("[^A-Za-z0-9]+") # [^찾을 패턴] : 찾을 패턴이 아닌것(not)
print(pattern.search("aa1234"))
print(pattern.search("A4567!@#$"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# None
# <re.Match object; span=(5, 9), match='!@#$'>
# None

# %%
pattern = re.compile("[가-힣]+") # 
print(pattern.search("aa1234대한민국"))
print(pattern.search("A4백두산567!@#$"))
print(pattern.search("ADDDDDDDDDDDDAA"))
# Out:
# <re.Match object; span=(6, 10), match='대한민국'>
# <re.Match object; span=(2, 5), match='백두산'>
# None

# %%
pattern = re.compile("[a-z]+") # 
print(pattern.search("aa1234대한민국"))
print(pattern.match("aa1234대한민국"))
# Out:
# <re.Match object; span=(0, 2), match='aa'>
# <re.Match object; span=(0, 2), match='aa'>

# %%
origin = "DDA D1A DDA DA"
# sub(패턴, 바꿀문자열, 원본문자열)
print(re.sub("D.A","Dave",origin))
# Out:
# Dave Dave Dave DA

# %%
pattern = re.compile("D.A")
pattern.sub("Dave",origin)
# Out:
# 'Dave Dave Dave DA'

# %%
# findall() : 표현식과 매칭되는 문자들을 리스트로 반환
pattern = re.compile("[a-z]+")
origin = "Game of Life in Python"

# pattern.findall(origin)
for w in pattern.findall(origin):
    print(w)
# Out:
# ame
# of
# ife
# in
# ython

# %%
for w in pattern.finditer(origin):
    print(w)
    print(w.group())
# match 객체로 돌아옴
# Out:
# <re.Match object; span=(1, 4), match='ame'>
# ame
# <re.Match object; span=(5, 7), match='of'>
# of
# <re.Match object; span=(9, 12), match='ife'>
# ife
# <re.Match object; span=(13, 15), match='in'>
# in
# <re.Match object; span=(17, 22), match='ython'>
# ython

# %%
pattern = re.compile(":")
pattern.split("python:java:javascript")
# Out:
# ['python', 'java', 'javascript']

# %%
# VS 로 문자열 분리 => ['python ', ' java']
origin = "python VS java VS VS  VS  "
pattern = re.compile(" VS ")
print(pattern.split(origin))

# - 기호를 * 로 바꿔서 출력
jumin = "801210-1011323"
pattern = re.compile("-")
print(pattern.sub("*", jumin))
# Out:
# ['python', 'java', 'VS ', ' ']
# 801210*1011323

# %%
# data_kr 엑셀 읽기
# 주민번호 뒷자리를 * 로 바꿔서 보여주기
from openpyxl import load_workbook

wb = load_workbook("./file/data_kr.xlsx")
ws = wb.active

pattern = re.compile(r"[0-9]{7}")

for row in ws.rows:
    print(re.sub(pattern, "*******", row[1].value))

wb.close()
# Out:
# 주민등록번호
# 800215-*******
# 821030-*******
# 841230-*******
# 790903-*******
# 800125-*******
# 820612-*******

# %%
origin = "<b>아이폰</b>"
# pattern = re.compile("<.*>") # 최대한 넓은 범위 매칭
# +?, *? : 매칭 최소화
pattern = re.compile("<.*?>") 
pattern.search(origin)
# Out:
# <re.Match object; span=(0, 3), match='<b>'>

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://www.naver.com")
soup = BeautifulSoup(res.text, "lxml")

# h 로 시작하는 모든 태그 요소 찾기
print(soup.find_all(string=re.compile(r"h\d")))
# soup.find_all("attrs=h")

# 이미지 요소 찾기(jpg or png)
soup.find_all("img", attrs={"src":re.compile(r".+\.jpg|png")})
# Out:
# ['\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"마스터는가야지","url":"https://chzzk.naver.com/live/8a59b34b46271960c1bf172bb0fac758","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Flivecloud-thumb.akamaized.net%2Fchzzk%2Flivecloud%2FKR%2Fstream%2F26441925%2Flive%2F6119649%2Frecord%2F28396296%2Fthumbnail%2Fimage_720.jpg%22&type=f504_292&service=navermain"},"highlight":"리그 오브 레전드","source":{"name":"앰비션","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fnng-phinf.pstatic.net%2FMjAyMzEyMThfODUg%2FMDAxNzAyODkwOTExNjcx.eNZNw7jE2uVB9ONNgYbpeCICvQSLOKQoNkXXiN3PbSMg.crVP8eb-RB4UvCjfFxXWYVUrhnj6X_LBnbiabbhwo8gg.PNG%2F%25EC%25A0%259C%25EB%25AA%25A9_%25EC%2597%2586%25EC%259D%258C-3.png%22&type=nf40_40&service=navermain"}},"chzzkLiveId":"6119649","showLiveBadge":true,"viewCount":"1,123","_id":"65308fd13c50cd9912162f6a"},{"@type":"MATERIAL-PC-FEED","title":"⚡삼국지14! 치수들과 합방⚡","url":"https://chzzk.naver.com/live/55e243bd868e55adf3524c85f8db51b5","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Flivecloud-thumb.akamaized.net%2Fchzzk%2Flivecloud%2FKR%2Fstream%2F26479658%2Flive%2F6117763%2Frecord%2F28392387%2Fthumbnail%2Fimage_720.jpg%22&type=f504_292&service=navermain"},"highlight":"삼국지14 with 파워업키트","source":{"name":"개복어","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fnng-phinf.pstatic.net%2FMjAyNDAyMjVfMjI5%2FMDAxNzA4ODUwMTYyNzEz.GzHwkVdRf6Tmn2yAHtX8i_AXQuCJKA-BFrM6MnDsPBkg.XR_AcTAYylgWtAx3C273tcP7DtPg57iTj96-ysnelGYg.PNG%2FKakaoTalk_20240225_173429236.png%22&type=nf40_40&service=navermain"}},"chzzkLiveId":"6117763","showLiveBadge":true,"viewCount":"733","_id":"65308fd13c50cd9912162f6b"},{"@type":"MATERIAL-PC-FEED","title":"엘든링 재활?훈련 feat 방패용사","url":"https://chzzk.naver.com/live/bee4b42475b5937226b8b7ccbe2eb2dc","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Flivecloud-thumb.akamaized.net%2Fchzzk%2Flivecloud%2FKR%2Fstream%2F26479964%2Flive%2F6118517%2Frecord%2F28394292%2Fthumbnail%2Fimage_720.jpg%22&type=f504_292&service=navermain"},"highlight":"엘든 링","source":{"name":"칸데르니아","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fnng-phinf.pstatic.net%2FMjAyMzEyMDZfMjc0%2FMDAxNzAxODI5NTAwMzQ1.tWiGOf27WjmRWaBfM24lGMX9Qz5CJzEuzU0wvTnL4KUg.8O9cCU8LcyqE4LgJVQxGQkCzogF8M3X67yHfXVxw0Jog.PNG%2F%25EB%25B9%25BC%25EA%25BC%25BC.png%22&type=nf40_40&service=navermain"}},"chzzkLiveId":"6118517","showLiveBadge":true,"viewCount":"703","_id":"654ad80598c6dbca70ba6ce6"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@template":"NONE"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"needCologger":false,"ad":false,"@type":"PC-FEED-BLOCK","@code":"PC-FEED-GAMEAPP-TOP-HIGHLIGHTED","@template":"HIGHLIGHTED-COLUMNS"},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"드렛지, 바다 낚시를 못 끊겠어요","url":"https://game.naver.com/original_series/72/temp/134188","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240527_1095%2Fupload_171680129595206MQr.jpg%22&type=nf308_200&service=navermain"},"source":{"name":"게임조선"},"showLiveBadge":false,"_id":"6441ca92c499cc07f334c4b3"},{"@type":"MATERIAL-PC-FEED","title":"헬다이버즈2 #보너스","url":"https://game.naver.com/original_series/21/temp/134442","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20240527_1095%2Fupload_1716801344295v7XYY.jpg%22&type=nf308_200&service=navermain"},"source":{"name":"스콜라"},"showLiveBadge":false,"_id":"6441ca92c499cc07f334c4b4"},{"@type":"MATERIAL-PC-FEED","title":"분신과 스태틱만 있으면 오공은 무적이다","url":"https://game.naver.com/origina ...
# []

# %%
from openpyxl import load_workbook

wb = load_workbook("./file/train.xlsx")
ws = wb.active

pattern = re.compile(r" Mr\.")

for row in ws.rows:
    if len(pattern.findall(row[3].value)) > 0:
        if pattern.findall(row[3].value)[0].strip() == "Mr.":
            print(row[3].value)
    # 그냥 "Mr." 으로하셔서 if를 두개 넣은듯 => "Mr." 으로하면 Mrs. 도 잡혀서그럼
wb.close()
# Out:
# Braund, Mr. Owen Harris
# Allen, Mr. William Henry
# Moran, Mr. James
# McCarthy, Mr. Timothy J
# Saundercock, Mr. William Henry
# Andersson, Mr. Anders Johan
# Williams, Mr. Charles Eugene
# Fynney, Mr. Joseph J
# Beesley, Mr. Lawrence
# Sloper, Mr. William Thompson
# Emir, Mr. Farred Chehab
# Fortune, Mr. Charles Alexander
# Todoroff, Mr. Lalio
# Wheadon, Mr. Edward H
# Meyer, Mr. Edgar Joseph
# Holverson, Mr. Alexander Oskar
# Mamee, Mr. Hanna
# Cann, Mr. Ernest Charles
# Kraeff, Mr. Theodor
# Rogers, Mr. William John
# Lennon, Mr. Denis
# Samaan, Mr. Youssef
# Nosworthy, Mr. Richard Cater
# Ostby, Mr. Engelhart Cornelius
# Woolner, Mr. Hugh
# Novel, Mr. Mansouer
# Sirayanian, Mr. Orsen
# Harris, Mr. Henry Birkhardt
# Stewart, Mr. Albert A
# Crease, Mr. Ernest James
# Alexander, Mr. William
# Lester, Mr. James
# Slemen, Mr. Richard James
# Tomlin, Mr. Ernest Portage
# Fry, Mr. Richard
# Mallet, Mr. Albert
# Holm, Mr. John Fredrik Alexander
# Lulic, Mr. Nikola
# Flynn, Mr. John
# Lam, Mr. Len
# McCormack, Mr. Thomas Joseph
# Saad, Mr. Amin
# Augustsson, Mr. Albert
# Allum, Mr. Owen George
# Pasic, Mr. Jakob
# Sirota, Mr. Maurice
# Chip, Mr. Chang
# Marechal, Mr. Pierre
# Alhomaki, Mr. Ilmari Rudolf
# Mudd, Mr. Thomas Charles
# Lemberopolous, Mr. Peter L
# Culumovic, Mr. Jeso
# Abbing, Mr. Anthony
# Sage, Mr. Douglas Bullen
# Markoff, Mr. Marin
# Svensson, Mr. Johan
# Daly, Mr. Peter Denis
# Razi, Mr. Raihed
# Hansen, Mr. Claus Peter
# Giles, Mr. Frederick Edward
# Gill, Mr. John William
# Roebling, Mr. Washington Augustus II
# van Melkebeke, Mr. Philemon
# Balkic, Mr. Cerin
# Carlsson, Mr. Frans Olof
# Vander Cruyssen, Mr. Victor
# Gustafsson, Mr. Alfred Ossian
# Petroff, Mr. Nedelio
# Laleff, Mr. Kristo
# Markun, Mr. Johann
# Banfield, Mr. Frederick James
# Sutehall, Mr. Henry Jr
# Behr, Mr. Karl Howell
# Dooley, Mr. Patrick

# %%
# Mr. == > 남성, Miss. ==> 미혼여성, Mrs. ==> 기혼여성, X
from openpyxl import Workbook

wb = load_workbook("./file/train.xlsx")
ws = wb.active

wb1 = Workbook()
work_sheet_man = wb1.active
work_sheet_man.column_dimensions["D"].width = 70
work_sheet_man.title = "남성"

work_sheet_women = wb1.create_sheet(title="기혼여성")
work_sheet_women.column_dimensions["D"].width = 70

work_sheet_solo_women = wb1.create_sheet(title="미혼여성")
work_sheet_solo_women.column_dimensions["D"].width = 70

work_sheet_others = wb1.create_sheet(title="기타")
work_sheet_others.column_dimensions["D"].width = 70


pattern = re.compile(r" [A-z]+\.")
list1 = []
for row in ws.rows:
    if pattern.search(row[3].value):
        data = pattern.search(row[3].value).group()
        # print(data)
    if row[0].row == 1:
        # for title in row:
        #     list1.append(title.value)
        # work_sheet_man.append(list1)
        # work_sheet_women.append(list1)
        # work_sheet_solo_women.append(list1)
        # work_sheet_others.append(list1)
        #  for문 생략(list1을 만들어 줄 필요가 없어짐)
        work_sheet_man.append([title.value for title in row]) 
        work_sheet_women.append([title.value for title in row])
        work_sheet_solo_women.append([title.value for title in row])
        work_sheet_others.append([title.value for title in row])
    else:
        # 1행 말고 다른줄도 전부 다 추가해줌
        # for col in row:
        #     list1.append(col.value)
        if data == " Mr." :
            work_sheet_man.append([col.value for col in row])
        elif data == " Mrs." :
            work_sheet_women.append([col.value for col in row])
        elif data == " Miss." :
            work_sheet_solo_women.append([col.value for col in row])
        else :
            work_sheet_others.append([col.value for col in row])


wb1.save("./file/train_gender.xlsx")
wb1.close() # 생성한 파일
wb.close() # 읽어온 파일
